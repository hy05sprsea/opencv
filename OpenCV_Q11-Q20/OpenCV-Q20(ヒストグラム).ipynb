# %%
import cv2
import matplotlib.pyplot as plt

img_dark = cv2.imread('imori_256x256_dark.png')
img_dark = cv2.cvtColor(img_dark, cv2.COLOR_BGR2RGB)
plt.imshow(img_dark)

# %%
plt.hist(img_dark.ravel(), bins=255, rwidth=0.8, range=(0, 255))
plt.show()
