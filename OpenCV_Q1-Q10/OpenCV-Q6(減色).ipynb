# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread("imori.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
def color_subtraction(img, div = 4):
    th = 256 // div
    return np.clip(img // th * th + th // 2, 0, 255)

img_sub = color_subtraction(img)
plt.imshow(img_sub)
plt.show()

# %%
aaa
